# %% [markdown]
# # Voltage Control for the IEEE 14-Bus Test Case
# ELEC 571: TERM PROJECT
#
# In this project, we use formulate and solve optimal control problems for the IEEE 14-bus system.  In particular, we compare two approaches:
# - **Model Predictive Control**, where the optimizaiton problem is solved online in a receding-horizon fashion, and
# - **Data-Driven Predictive Control**, where the optimization problem is ___ .
#
# OVERVIEW:
# 1. Package imports
# 2. Generate **simulation data** using ANDES for the IEEE 14-bus system with disturbances. Problem setup. This includes loading case file and disturbances.
# 3. **System Identification** using SIPPY from the inputs and outputs of the system.
# 4. **Verification** of estimated system ID parameters.
# 5. MPC

# %% [markdown]
# ### Package imports

# %%
#%% Package imports

# Install the Python control library
# %pip install -q control

# Numerical and CVXPY packages
import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt
import andes
from sippy_unipi import system_identification as sysid
import casadi as ca 
from control import ss


# Plotting
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
plt.style.use('tableau-colorblind10')

# %%
x = np.zeros((4, 1))
y = np.ones((4, 1))

idx = x==y
print(idx)

# %% [markdown]
# ### Generate Dynamic Simulation Data
#
# ---
#
# Load the IEEE 14-bus test case and run an open loop simulation to collect data.
# The case file (.xlsx) contains all model information as well as disturbances.
#
# The system contains 14 buses, 5 synchronous generators, 11 loads.
# We are interested in voltage and frequency control.
#
# ANDES is an open-source Python library for dynamic simulation tool for power systems.
#
# The ultimate goal is to achieve transient stability. This means voltage and frequency control despite disturbances such as fault, load variation, etc.
# - **Inputs**: There are three controllable loads at buses X, Y, and Z, where the active power may be manipulated to achieve transient stability.
# - **Outputs**: We are interested in voltages at buses 2, 4, 7 and 9.
#
# Simulation duration is 20 seconds with a time-step of $1/30 \approx 33.3$ ms.
#
# **Disturbances**: Persistent excitation via a 5-second chirp is applied for system identification. The chirp signal is of the form:
# $$u_t = P_t + A_P * \sin (0.2 \pi t^2)$$
#
# where $A_P$ is the amplitude of the chirp signal and is given by 0.03 p.u., 0.02 p.u.and 0.02 p.u. for loads 1, 2 and 10, respectively. $P_t$ is the current active power of each load. The inputs are zero otherwise. $u_t^{(1)}$, $u_t^{(2)}$, and $u_t^{(3)}$, correspond to the active loads at buses 2, 3 and 13. See figure below for more details.
# $$ u_t = \begin{bmatrix}
# u_t^{(1)} \\
# u_t^{(2)} \\
# u_t^{(3)}
# \end{bmatrix}
# $$
# ![alt text](Figures/Single-line-diagram-of-the-IEEE-14-bus-test-system.png "Single-line-diagram-of-the-IEEE-14-bus-test-system")

# %%
# Simulation parameters
T_END = 20.0 # seconds
dt = 1/50 # time step = 0.020 seconds = 20.0 ms
K = round(T_END/dt + 1) # number of simulation steps (incl t = 0)
print(K)
# Outputs
p = 5 # Number of outputs; 4 voltages + 1 freq dev

# Inputs 
m = 3 # Number of inputs

# Disturbances
u = np.zeros((K, m))
for i in range(K):
    if i*dt <= 5:
        u[i, 0] = 0.03 * np.sin(2*np.pi * 0.5 * (i*dt)**2 /5)
    elif i*dt>=6 and i*dt <= 11: 
        u[i, 1] = 0.02 * np.sin(2*np.pi * 0.5 * (i*dt - 6)**2 /5)
    elif i*dt >=12 and i*dt <= 17:
        u[i, 2] = 0.02 * np.sin(2*np.pi * 0.5 * (i*dt - 12)**2 /5)
# Out:
# 1001

# %%
#%% Generate data for system identification

# Load the system case
case = 'IEEE_cases/ieee14_alter_v2.xlsx'  

ssys = andes.load(case)

# Set load to constant active and reactive power (ANDES requirement)
ssys.PQ.config.p2p = 1.0
ssys.PQ.config.p2i = 0
ssys.PQ.config.p2z = 0

ssys.PQ.config.q2q = 1.0
ssys.PQ.config.q2i = 0
ssys.PQ.config.q2z = 0

# Run power flow simulation - initializes system
ssys.PFlow.run()

# Run dynamic simulation for 20 seconds
ssys.TDS.config.tf = T_END
ssys.TDS.config.tstep = dt
print('Running ANDES dynamic simulation...')
ssys.TDS.run()
print('Simulation finished')

# Plotting the results
ssys.TDS.load_plotter()
fig, ax = ssys.TDS.plt.plot(ssys.GENROU.omega)
plt.show()
fig.savefig("IEEE14_omega_plot.png", dpi=300)

fig, ax = ssys.TDS.plt.plot(ssys.GENROU.v)
fig.savefig("IEEE14_v_plot.png", dpi=300)
# Out:
# Running ANDES dynamic simulation...
#   0%|          | 0/100 [00:00<?, ?%/s]
# <Alter 2>: set PQ.PQ_1.Ppf.v=0.217021 at t=0.0333333. Previous value was 0.217.
# <Alter 3>: set PQ.PQ_1.Ppf.v=0.217105 at t=0.0666667. Previous value was 0.217021.
# <Alter 4>: set PQ.PQ_1.Ppf.v=0.217293 at t=0.1. Previous value was 0.217105.
# <Alter 5>: set PQ.PQ_1.Ppf.v=0.217628 at t=0.133333. Previous value was 0.217293.
# <Alter 6>: set PQ.PQ_1.Ppf.v=0.218152 at t=0.166667. Previous value was 0.217628.
# <Alter 7>: set PQ.PQ_1.Ppf.v=0.218906 at t=0.2. Previous value was 0.218152.
# <Alter 8>: set PQ.PQ_1.Ppf.v=0.219932 at t=0.233333. Previous value was 0.218906.
# <Alter 9>: set PQ.PQ_1.Ppf.v=0.221272 at t=0.266667. Previous value was 0.219932.
# <Alter 10>: set PQ.PQ_1.Ppf.v=0.222967 at t=0.3. Previous value was 0.221272.
# <Alter 11>: set PQ.PQ_1.Ppf.v=0.22506 at t=0.333333. Previous value was 0.222967.
# <Alter 12>: set PQ.PQ_1.Ppf.v=0.227591 at t=0.366667. Previous value was 0.22506.
# <Alter 13>: set PQ.PQ_1.Ppf.v=0.230602 at t=0.4. Previous value was 0.227591.
# <Alter 14>: set PQ.PQ_1.Ppf.v=0.234133 at t=0.433333. Previous value was 0.230602.
# <Alter 15>: set PQ.PQ_1.Ppf.v=0.238226 at t=0.466667. Previous value was 0.234133.
# <Alter 16>: set PQ.PQ_1.Ppf.v=0.242919 at t=0.5. Previous value was 0.238226.
# <Alter 17>: set PQ.PQ_1.Ppf.v=0.248252 at t=0.533333. Previous value was 0.242919.
# <Alter 18>: set PQ.PQ_1.Ppf.v=0.254264 at t=0.566667. Previous value was 0.248252.
# <Alter 19>: set PQ.PQ_1.Ppf.v=0.260992 at t=0.6. Previous value was 0.254264.
# <Alter 20>: set PQ.PQ_1.Ppf.v=0.268473 at t=0.633333. Previous value was 0.260992.
# <Alter 21>: set PQ.PQ_1.Ppf.v=0.276742 at t=0.666667. Previous value was 0.268473.
# <Alter 22>: set PQ.PQ_1.Ppf.v=0.285833 at t=0.7. Previous value was 0.276742.
# <Alter 23>: set PQ.PQ_1.Ppf.v=0.295778 at t=0.733333. Previous value was 0.285833.
# <Alter 24>: set PQ.PQ_1.Ppf.v=0.306607 at t=0.766667. Previous value was 0.295778.
# <Alter 25>: set PQ.PQ_1.Ppf.v=0.318348 at t=0.8. Previous value was 0.306607.
# <Alter 26>: set PQ.PQ_1.Ppf.v=0.331027 at t=0.833333. Previous value was 0.318348.
# <Alter 27>: set PQ.PQ_1.Ppf.v=0.344665 at t=0.866667. Previous value was 0.331027.
# <Alter 28>: set PQ.PQ_1.Ppf.v=0.359283 at t=0.9. Previous value was 0.344665.
# <Alter 29>: set PQ.PQ_1.Ppf.v=0.374895 at t=0.933333. Previous value was 0.359283.
# <Alter 30>: set PQ.PQ_1.Ppf.v=0.391514 at t=0.966667. Previous value was 0.374895.
# <Alter 31>: set PQ.PQ_1.Ppf.v=0.409148 at t=1. Previous value was 0.391514.
# <Alter 32>: set PQ.PQ_1.Ppf.v=0.427799 at t=1.03333. Previous value was 0.409148.
# <Alter 33>: set PQ.PQ_1.Ppf.v=0.447465 at t=1.06667. Previous value was 0.427799.
# <Alter 34>: set PQ.PQ_1.Ppf.v=0.468138 at t=1.1. Previous value was 0.447465.
# <Alter 35>: set PQ.PQ_1.Ppf.v=0.489806 at t=1.13333. Previous value was 0.468138.
# <Alter 36>: set PQ.PQ_1.Ppf.v=0.512447 at t=1.16667. Previous value was 0.489806.
# <Alter 37>: set PQ.PQ_1.Ppf.v=0.536035 at t=1.2. Previous value was 0.512447.
# <Alter 38>: set PQ.PQ_1.Ppf.v=0.560538 at t=1.23333. Previous value was 0.536035.
# <Alter 39>: set PQ.PQ_1.Ppf.v=0.585912 at t=1.26667. Previous value was 0.560538.
# <Alter 40>: set PQ.PQ_1.Ppf.v=0.61211 at t=1.3. Previous value was 0.585912.
# <Alter 41>: set PQ.PQ_1.Ppf.v=0.639074 at t=1.33333. Previous value was 0.61211.
# <Alter 42>: set PQ.PQ_1.Ppf.v=0.666738 at t=1.36667. Previous value was 0.639074.
# <Alter 43>: set PQ.PQ_1.Ppf.v=0.695028 at t=1.4. Previous value was 0.666738.
# <Alter 44>: set PQ.PQ_1.Ppf.v=0.72386 at t=1.43333. Previous value was 0.695028.
# <Alter 45>: set PQ.PQ_1.Ppf.v=0.753142 at t=1.46667. Previous value was 0.72386.
# <Alter 46>: set PQ.PQ_1.Ppf.v=0.782773 at t=1.5. Previous value was 0.753142.
# <Alter 47>: set PQ.PQ_1.Ppf.v=0.812641 at t=1.53333. Previous value was 0.782773.
# <Alter 48>: set PQ.PQ_1.Ppf.v=0.842629 at t=1.56667. Previous value was 0.812641.
# <Alter 49>: set PQ.PQ_1.Ppf.v=0.872608 at t=1.6. Previous value was 0.842629.
# <Alter 50>: set PQ.PQ_1.Ppf.v=0.902441 at t=1.63333. Previous value was 0.872608.
# <Alter 51>: set PQ.PQ_1.Ppf.v=0.931985 at t=1.66667. Previous value was 0.902441.
# <Alter 52>: set PQ.PQ_1.Ppf.v=0.961089 at t=1.7. Previous value was 0.931985.
# <Alter 53>: set PQ.PQ_1.Ppf.v=0.989595 at t=1.73333. Previous value was 0.961089.
# <Alter 54>: set PQ.PQ_1.Ppf.v=1.01734 at t=1.76667. Previous value was 0.989595.
# <Alter 55>: set PQ.PQ_1.Ppf.v=1.04415 at t=1.8. Previous value was 1.01734.
# <Alter 56>: set PQ.PQ_1.Ppf.v=1.06987 at t=1.83333. Previous value was 1.04415.
# <Alter 57>: set PQ.PQ_1.Ppf.v=1.09431 at t=1.86667. Previous value was 1.06987.
# <Alter 58>: set PQ.PQ_1.Ppf.v=1.11731 at t=1.9. Previous value was 1.09431.
# <Alter 59>: set PQ.PQ_1.Ppf.v=1.13868 at t=1.93333. Previous value was 1.11731.
# <Alter 60>: set PQ.PQ_1.Ppf.v=1.15827 at t=1.96667. Previous value was 1.13868.
# <Alter 61>: set PQ.PQ_1.Ppf.v=1.1759 at t=2. Previous value was 1.15827.
# <Alter 62>: set PQ.PQ_1.Ppf.v=1.19142 at t=2.03333. Previous value was 1.1759.
# <Alter 63>: set PQ.PQ_1.Ppf.v=1.20469 at t=2.06667. Previous value was 1.19142.
# <Alter 64>: set PQ.PQ_1.Ppf.v=1.21556 at t=2.1. Previous value was 1.20469.
# <Alter 65>: set PQ.PQ_1.Ppf.v=1.22391 at t=2.13333. Previous value was 1.21556.
# <Alter 66>: set PQ.PQ_1.Ppf.v=1.22963 at t=2.16667. Previous value was 1.22391.
# <Alter 67>: set PQ.PQ_1.Ppf.v=1.23264 at t=2.2. Previous value was 1.22963.
# <Alter 68>: set PQ.PQ_1.Ppf.v=1.23287 at t=2.23333. Previous value was 1.23264.
# <Alter 69>: set PQ.PQ_1.Ppf.v=1.23028 at t=2.26667. Previous value was 1.23287.
# <Alter 70>: set PQ.PQ_1.Ppf.v=1.22484 at t=2.3. Previous value was 1.23028.
# <Alter 71>: set PQ.PQ_1.Ppf.v=1.21657 at t=2.33333. Previous value was 1.22484.
# <Alter 72>: set PQ.PQ_1.Ppf.v=1.20551 at t=2.36667. Previous value was 1.21657.
# <Alter 73>: set PQ.PQ_1.Ppf.v=1.19172 at t=2.4. Previous value was 1.20551.
# <Alter 74>: set PQ.PQ_1.Ppf.v=1.17531 at t=2.43333. Previous value was 1.19172.
# <Alter 75>: set PQ.PQ_1.Ppf.v=1.15642 at t=2.46667. Previous value was 1.17531.
# <Alter 76>: set PQ.PQ_1.Ppf.v=1.1352 at t=2.5. Previous value was 1.15642.
# <Alter 77>: set PQ.PQ_1.Ppf.v=1.11188 at t=2.53333. Previous value was 1.1352.
# <Alter 78>: set PQ.PQ_1.Ppf.v=1.08667 at t=2.56667. Previous value was 1.11188.
# <Alter 79>: set PQ.PQ_1.Ppf.v=1.05986 at t=2.6. Previous value was 1.08667.
# <Alter 80>: set PQ.PQ_1.Ppf.v=1.03173 at t=2.63333. Previous value was 1.05986.
# <Alter 81>: set PQ.PQ_1.Ppf.v=1.00262 at t=2.66667. Previous value was 1.03173.
# <Alter 82>: set PQ.PQ_1.Ppf.v=0.972882 at t=2.7. Previous value was 1.00262.
# <Alter 83>: set PQ.PQ_1.Ppf.v=0.942887 at t=2.73333. Previous value was 0.972882.
# <Alter 84>: set PQ.PQ_1.Ppf.v=0.913028 at t=2.76667. Previous value was 0.942887.
# <Alter 85>: set PQ.PQ_1.Ppf.v=0.88371 at t=2.8. Previous value was 0.913028.
# <Alter 86>: set PQ.PQ_1.Ppf.v=0.855344 at t=2.83333. Previous value was 0.88371.
# <Alter 87>: set PQ.PQ_1.Ppf.v=0.828344 at t=2.86667. Previous value was 0.855344.
# <Alter 88>: set PQ.PQ_1.Ppf.v=0.803115 at t=2.9. Previous value was 0.828344.
# <Alter 89>: set PQ.PQ_1.Ppf.v=0.780053 at t=2.93333. Previous value was 0.803115.
# <Alter 90>: set PQ.PQ_1.Ppf.v=0.759532 at t=2.96667. Previous value was 0.780053.
# <Alter 91>: set PQ.PQ_1.Ppf.v=0.741899 at t=3. Previous value was 0.759532.
# <Alter 92>: set PQ.PQ_1.Ppf.v=0.727464 at t=3.03333. Previous value was 0.741899.
# <Alter 93>: set PQ.PQ_1.Ppf.v=0.716499 at t=3.06667. Previous value was 0.727464.
# <Alter 94>: set PQ.PQ_1.Ppf.v=0.709221 at t=3.1. Previous value was 0.716499.
# <Alter 95>: set PQ.PQ_1.Ppf.v=0.705793 at t=3.13333. Previous value was 0.709221.
# <Alter 96>: set PQ.PQ_1.Ppf.v=0.706317 at t=3.16667. Previous value was 0.705793.
# <Alter 97>: set PQ.PQ_1.Ppf.v=0.710824 at t=3.2. Previous value was 0.706317.
# <Alter 98>: set PQ.PQ_1.Ppf.v=0.719274 at t=3.23333. Previous value was 0.710824.
# <Alter 99>: set PQ.PQ_1.Ppf.v=0.731552 at t=3.26667. Previous value was 0.719274.
# <Alter 100>: set PQ.PQ_1.Ppf.v=0.747468 at t=3.3. Previous value was 0.731552.
# <Alter 101>: set PQ.PQ_1.Ppf.v=0.766751 at t=3.33333. Previous value was 0.747468.
# <Alter 102>: set PQ.PQ_1.Ppf.v=0.78906 at t=3.36667. Previous value was 0.766751.
# <Alter 103>: set PQ.PQ_1.Ppf.v=0.813978 at t=3.4. Previous value was 0.78906.
# <Alter 104>: set PQ.PQ_1.Ppf.v=0.841024 at t=3.43333. Previous value was 0.813978.
# <Alter 105>: set PQ.PQ_1.Ppf.v=0.869657 at t=3.46667. Previous value was 0.841024.
# <Alter 106>: set PQ.PQ_1.Ppf.v=0.899288 at t=3.5. Previous value was 0.869657.
# <Alter 107>: set PQ.PQ_1.Ppf.v=0.929286 at t=3.53333. Previous value was 0.899288.
# <Alter 108>: set PQ.PQ_1.Ppf.v=0.958997 at t=3.56667. Previous value was 0.929286.
# <Alter 109>: set PQ.PQ_1.Ppf.v=0.987753 at t=3.6. Previous value was 0.958997.
# <Alter 110>: set PQ.PQ_1.Ppf.v=1.01489 at t=3.63333. Previous value was 0.987753.
# <Alter 111>: set PQ.PQ_1.Ppf.v=1.03976 at t=3.66667. Previous value was 1.01489.
# <Alter 112>: set PQ.PQ_1.Ppf.v=1.06176 at t=3.7. Previous value was 1.03976.
# <Alter 113>: set PQ.PQ_1.Ppf.v=1.08033 at t=3.73333. Previous value was 1.06176.
# <Alter 114>: set PQ.PQ_1.Ppf.v=1.09498 at t=3.76667. Previous value was 1.08033.
# <Alter 115>: set PQ.PQ_1.Ppf.v=1.10532 at t=3.8. Previous value was 1.09498.
# <Alter 116>: set PQ.PQ_1.Ppf.v=1.11104 at t=3.83333. Previous value was 1.10532.
# <Alter 117>: set PQ.PQ_1.Ppf.v=1.11197 at t=3.86667. Previous value was 1.11104.
# <Alter 118>: set PQ.PQ_1.Ppf.v=1.10802 at t=3.9. Previous value was 1.11197.
# <Alter 119>: set PQ.PQ_1.Ppf.v=1.09927 at t=3.93333. Previous value was 1.10802.
# <Alter 120>: set PQ.PQ_1.Ppf.v=1.08591 at t=3.96667. Previous value was 1.09927.
# <Alter 121>: set PQ.PQ_1.Ppf.v=1.06828 at t=4. Previous value was 1.08591.
# <Alter 122>: set PQ.PQ_1.Ppf.v=1.04683 at t=4.03333. Previous value was 1.06828.
# <Alter 123>: set PQ.PQ_1.Ppf.v=1.02214 at t=4.06667. Previous value was 1.04683.
# <Alter 124>: set PQ.PQ_1.Ppf.v=0.99492 at t=4.1. Previous value was 1.02214.
# <Alter 125>: set PQ.PQ_1.Ppf.v=0.965937 at t=4.13333. Previous value was 0.99492.
# <Alter 126>: set PQ.PQ_1.Ppf.v=0.936051 at t=4.16667. Previous value was 0.965937.
# <Alter 127>: set PQ.PQ_1.Ppf.v=0.906167 at t=4.2. Previous value was 0.936051.
# <Alter 128>: set PQ.PQ_1.Ppf.v=0.877211 at t=4.23333. Previous value was 0.906167.
# <Alter 129>: set PQ.PQ_1.Ppf.v=0.850102 at t=4.26667. Previous value was 0.877211.
# <Alter 130>: set PQ.PQ_1.Ppf.v=0.825721 at t=4.3. Previous value was 0.850102.
# <Alter 131>: set PQ.PQ_1.Ppf.v=0.804882 at t=4.33333. Previous value was 0.825721.
# <Alter 132>: set PQ.PQ_1.Ppf.v=0.788297 at t=4.36667. Previous value was 0.804882.
# <Alter 133>: set PQ.PQ_1.Ppf.v=0.776556 at t=4.4. Previous value was 0.788297.
# <Alter 134>: set PQ.PQ_1.Ppf.v=0.770094 at t=4.43333. Previous value was 0.776556.
# <Alter 135>: set PQ.PQ_1.Ppf.v=0.769172 at t=4.46667. Previous value was 0.770094.
# <Alter 136>: set PQ.PQ_1.Ppf.v=0.773865 at t=4.5. Previous value was 0.769172.
# <Alter 137>: set PQ.PQ_1.Ppf.v=0.784047 at t=4.53333. Previous value was 0.773865.
# <Alter 138>: set PQ.PQ_1.Ppf.v=0.79939 at t=4.56667. Previous value was 0.784047.
# <Alter 139>: set PQ.PQ_1.Ppf.v=0.819371 at t=4.6. Previous value was 0.79939.
# <Alter 140>: set PQ.PQ_1.Ppf.v=0.843279 at t=4.63333. Previous value was 0.819371.
# <Alter 141>: set PQ.PQ_1.Ppf.v=0.870243 at t=4.66667. Previous value was 0.843279.
# <Alter 142>: set PQ.PQ_1.Ppf.v=0.899253 at t=4.7. Previous value was 0.870243.
# <Alter 143>: set PQ.PQ_1.Ppf.v=0.929199 at t=4.73333. Previous value was 0.899253.
# <Alter 144>: set PQ.PQ_1.Ppf.v=0.95891 at t=4.76667. Previous value was 0.929199.
# <Alter 145>: set PQ.PQ_1.Ppf.v=0.9872 at t=4.8. Previous value was 0.95891.
# <Alter 146>: set PQ.PQ_1.Ppf.v=1.01291 at t=4.83333. Previous value was 0.9872.
# <Alter 147>: set PQ.PQ_1.Ppf.v=1.03498 at t=4.86667. Previous value was 1.01291.
# <Alter 148>: set PQ.PQ_1.Ppf.v=1.05246 at t=4.9. Previous value was 1.03498.
# <Alter 149>: set PQ.PQ_1.Ppf.v=1.06459 at t=4.93333. Previous value was 1.05246.
# <Alter 150>: set PQ.PQ_1.Ppf.v=1.07081 at t=4.96667. Previous value was 1.06459.
# <Alter 151>: set PQ.PQ_1.Ppf.v=1.07081 at t=5. Previous value was 1.07081.
# <Alter 152>: set PQ.PQ_2.Ppf.v=0.5 at t=6. Previous value was 0.5.
# <Alter 153>: set PQ.PQ_2.Ppf.v=0.500014 at t=6.03333. Previous value was 0.5.
# <Alter 154>: set PQ.PQ_2.Ppf.v=0.50007 at t=6.06667. Previous value was 0.500014.
# <Alter 155>: set PQ.PQ_2.Ppf.v=0.500195 at t=6.1. Previous value was 0.50007.
# <Alter 156>: set PQ.PQ_2.Ppf.v=0.500419 at t=6.13333. Previous value was 0.500195.
# <Alter 157>: set PQ.PQ_2.Ppf.v=0.500768 at t=6.16667. Previous value was 0.500419.
# <Alter 158>: set PQ.PQ_2.Ppf.v=0.501271 at t=6.2. Previous value was 0.500768.
# <Alter 159>: set PQ.PQ_2.Ppf.v=0.501955 at t=6.23333. Previous value was 0.501271.
# <Alter 160>: set PQ.PQ_2.Ppf.v=0.502848 at t=6.26667. Previous value was 0.501955.
# <Alter 161>: set PQ.PQ_2.Ppf.v=0.503978 at t=6.3. Previous value was 0.502848.
# <Alter 162>: set PQ.PQ_2.Ppf.v=0.505373 at t=6.33333. Previous value was 0.503978.
# <Alter 163>: set PQ.PQ_2.Ppf.v=0.507061 at t=6.36667. Previous value was 0.505373.
# <Alter 164>: set PQ.PQ_2.Ppf.v=0.509068 at t=6.4. Previous value was 0.507061.
# <Alter 165>: set PQ.PQ_2.Ppf.v=0.511422 at t=6.43333. Previous value was 0.509068.
# <Alter 166>: set PQ.PQ_2.Ppf.v=0.51415 at t=6.46667. Previous value was 0.511422.
# <Alter 167>: set PQ.PQ_2.Ppf.v=0.517279 at t=6.5. Previous value was 0.51415.
# <Alter 168>: set PQ.PQ_2.Ppf.v=0.520835 at t=6.53333. Previous value was 0.517279.
# <Alter 169>: set PQ.PQ_2.Ppf.v=0.524842 at t=6.56667. Previous value was 0.520835.
# <Alter 170>: set PQ.PQ_2.Ppf.v=0.529328 at t=6.6. Previous value was 0.524842.
# <Alter 171>: set PQ.PQ_2.Ppf.v=0.534315 at t=6.63333. Previous value was 0.529328.
# <Alter 172>: set PQ.PQ_2.Ppf.v=0.539828 at t=6.66667. Previous value was 0.534315.
# <Alter 173>: set PQ.PQ_2.Ppf.v=0.545889 at t=6.7. Previous value was 0.539828.
# <Alter 174>: set PQ.PQ_2.Ppf.v=0.552519 at t=6.73333. Previous value was 0.545889.
# <Alter 175>: set PQ.PQ_2.Ppf.v=0.559738 at t=6.76667. Previous value was 0.552519.
# <Alter 176>: set PQ.PQ_2.Ppf.v=0.567566 at t=6.8. Previous value was 0.559738.
# <Alter 177>: set PQ.PQ_2.Ppf.v=0.576018 at t=6.83333. Previous value was 0.567566.
# <Alter 178>: set PQ.PQ_2.Ppf.v=0.58511 at t=6.86667. Previous value was 0.576018.
# <Alter 179>: set PQ.PQ_2.Ppf.v=0.594855 at t=6.9. Previous value was 0.58511.
# <Alter 180>: set PQ.PQ_2.Ppf.v=0.605264 at t=6.93333. Previous value was 0.594855.
# <Alter 181>: set PQ.PQ_2.Ppf.v=0.616343 at t=6.96667. Previous value was 0.605264.
# <Alter 182>: set PQ.PQ_2.Ppf.v=0.628099 at t=7. Previous value was 0.616343.
# <Alter 183>: set PQ.PQ_2.Ppf.v=0.640533 at t=7.03333. Previous value was 0.628099.
# <Alter 184>: set PQ.PQ_2.Ppf.v=0.653643 at t=7.06667. Previous value was 0.640533.
# <Alter 185>: set PQ.PQ_2.Ppf.v=0.667425 at t=7.1. Previous value was 0.653643.
# <Alter 186>: set PQ.PQ_2.Ppf.v=0.68187 at t=7.13333. Previous value was 0.667425.
# <Alter 187>: set PQ.PQ_2.Ppf.v=0.696965 at t=7.16667. Previous value was 0.68187.
# <Alter 188>: set PQ.PQ_2.Ppf.v=0.71269 at t=7.2. Previous value was 0.696965.
# <Alter 189>: set PQ.PQ_2.Ppf.v=0.729025 at t=7.23333. Previous value was 0.71269.
# <Alter 190>: set PQ.PQ_2.Ppf.v=0.745942 at t=7.26667. Previous value was 0.729025.
# <Alter 191>: set PQ.PQ_2.Ppf.v=0.763407 at t=7.3. Previous value was 0.745942.
# <Alter 192>: set PQ.PQ_2.Ppf.v=0.781383 at t=7.33333. Previous value was 0.763407.
# <Alter 193>: set PQ.PQ_2.Ppf.v=0.799825 at t=7.36667. Previous value was 0.781383.
# <Alter 194>: set PQ.PQ_2.Ppf.v=0.818685 at t=7.4. Previous value was 0.799825.
# <Alter 195>: set PQ.PQ_2.Ppf.v=0.837907 at t=7.43333. Previous value was 0.818685.
# <Alter 196>: set PQ.PQ_2.Ppf.v=0.857428 at t=7.46667. Previous value was 0.837907.
# <Alter 197>: set PQ.PQ_2.Ppf.v=0.877182 at t=7.5. Previous value was 0.857428.
# <Alter 198>: set PQ.PQ_2.Ppf.v=0.897094 at t=7.53333. Previous value was 0.877182.
# <Alter 199>: set PQ.PQ_2.Ppf.v=0.917086 at t=7.56667. Previous value was 0.897094.
# <Alter 200>: set PQ.PQ_2.Ppf.v=0.937072 at t=7.6. Previous value was 0.917086.
# <Alter 201>: set PQ.PQ_2.Ppf.v=0.956961 at t=7.63333. Previous value was 0.937072.
# <Alter 202>: set PQ.PQ_2.Ppf.v=0.976657 at t=7.66667. Previous value was 0.956961.
# <Alter 203>: set PQ.PQ_2.Ppf.v=0.99606 at t=7.7. Previous value was 0.976657.
# <Alter 204>: set PQ.PQ_2.Ppf.v=1.01506 at t=7.73333. Previous value was 0.99606.
# <Alter 205>: set PQ.PQ_2.Ppf.v=1.03356 at t=7.76667. Previous value was 1.01506.
# <Alter 206>: set PQ.PQ_2.Ppf.v=1.05144 at t=7.8. Previous value was 1.03356.
# <Alter 207>: set PQ.PQ_2.Ppf.v=1.06858 at t=7.83333. Previous value was 1.05144.
# <Alter 208>: set PQ.PQ_2.Ppf.v=1.08487 at t=7.86667. Previous value was 1.06858.
# <Alter 209>: set PQ.PQ_2.Ppf.v=1.1002 at t=7.9. Previous value was 1.08487.
# <Alter 210>: set PQ.PQ_2.Ppf.v=1.11445 at t=7.93333. Previous value was 1.1002.
# <Alter 211>: set PQ.PQ_2.Ppf.v=1.12751 at t=7.96667. Previous value was 1.11445.
# <Alter 212>: set PQ.PQ_2.Ppf.v=1.13927 at t=8. Previous value was 1.12751.
# <Alter 213>: set PQ.PQ_2.Ppf.v=1.14962 at t=8.03333. Previous value was 1.13927.
# <Alter 214>: set PQ.PQ_2.Ppf.v=1.15846 at t=8.06667. Previous value was 1.14962.
# <Alter 215>: set PQ.PQ_2.Ppf.v=1.1657 at t=8.1. Previous value was 1.15846.
# <Alter 216>: set PQ.PQ_2.Ppf.v=1.17127 at t=8.13333. Previous value was 1.1657.
# <Alter 217>: set PQ.PQ_2.Ppf.v=1.17509 at t=8.16667. Previous value was 1.17127.
# <Alter 218>: set PQ.PQ_2.Ppf.v=1.17709 at t=8.2. Previous value was 1.17509.
# <Alter 219>: set PQ.PQ_2.Ppf.v=1.17725 at t=8.23333. Previous value was 1.17709.
# <Alter 220>: set PQ.PQ_2.Ppf.v=1.17552 at t=8.26667. Previous value was 1.17725.
# <Alter 221>: set PQ.PQ_2.Ppf.v=1.17189 at t=8.3. Previous value was 1.17552.
# <Alter 222>: set PQ.PQ_2.Ppf.v=1.16638 at t=8.33333. Previous value was 1.17189.
# <Alter 223>: set PQ.PQ_2.Ppf.v=1.15901 at t=8.36667. Previous value was 1.16638.
# <Alter 224>: set PQ.PQ_2.Ppf.v=1.14981 at t=8.4. Previous value was 1.15901.
# <Alter 225>: set PQ.PQ_2.Ppf.v=1.13888 at t=8.43333. Previous value was 1.14981.
# <Alter 226>: set PQ.PQ_2.Ppf.v=1.12628 at t=8.46667. Previous value was 1.13888.
# <Alter 227>: set PQ.PQ_2.Ppf.v=1.11214 at t=8.5. Previous value was 1.12628.
# <Alter 228>: set PQ.PQ_2.Ppf.v=1.09658 at t=8.53333. Previous value was 1.11214.
# <Alter 229>: set PQ.PQ_2.Ppf.v=1.07978 at t=8.56667. Previous value was 1.09658.
# <Alter 230>: set PQ.PQ_2.Ppf.v=1.0619 at t=8.6. Previous value was 1.07978.
# <Alter 231>: set PQ.PQ_2.Ppf.v=1.04315 at t=8.63333. Previous value was 1.0619.
# <Alter 232>: set PQ.PQ_2.Ppf.v=1.02375 at t=8.66667. Previous value was 1.04315.
# <Alter 233>: set PQ.PQ_2.Ppf.v=1.00392 at t=8.7. Previous value was 1.02375.
# <Alter 234>: set PQ.PQ_2.Ppf.v=0.983924 at t=8.73333. Previous value was 1.00392.
# <Alter 235>: set PQ.PQ_2.Ppf.v=0.964018 at t=8.76667. Previous value was 0.983924.
# <Alter 236>: set PQ.PQ_2.Ppf.v=0.944473 at t=8.8. Previous value was 0.964018.
# <Alter 237>: set PQ.PQ_2.Ppf.v=0.925563 at t=8.83333. Previous value was 0.944473.
# <Alter 238>: set PQ.PQ_2.Ppf.v=0.907562 at t=8.86667. Previous value was 0.925563.
# <Alter 239>: set PQ.PQ_2.Ppf.v=0.890744 at t=8.9. Previous value was 0.907562.
# <Alter 240>: set PQ.PQ_2.Ppf.v=0.875369 at t=8.93333. Previous value was 0.890744.
# <Alter 241>: set PQ.PQ_2.Ppf.v=0.861688 at t=8.96667. Previous value was 0.875369.
# <Alter 242>: set PQ.PQ_2.Ppf.v=0.849933 at t=9. Previous value was 0.861688.
# <Alter 243>: set PQ.PQ_2.Ppf.v=0.84031 at t=9.03333. Previous value was 0.849933.
# <Alter 244>: set PQ.PQ_2.Ppf.v=0.832999 at t=9.06667. Previous value was 0.84031.
# <Alter 245>: set PQ.PQ_2.Ppf.v=0.828147 at t=9.1. Previous value was 0.832999.
# <Alter 246>: set PQ.PQ_2.Ppf.v=0.825862 at t=9.13333. Previous value was 0.828147.
# <Alter 247>: set PQ.PQ_2.Ppf.v=0.826211 at t=9.16667. Previous value was 0.825862.
# <Alter 248>: set PQ.PQ_2.Ppf.v=0.829216 at t=9.2. Previous value was 0.826211.
# <Alter 249>: set PQ.PQ_2.Ppf.v=0.834849 at t=9.23333. Previous value was 0.829216.
# <Alter 250>: set PQ.PQ_2.Ppf.v=0.843035 at t=9.26667. Previous value was 0.834849.
# <Alter 251>: set PQ.PQ_2.Ppf.v=0.853645 at t=9.3. Previous value was 0.843035.
# <Alter 252>: set PQ.PQ_2.Ppf.v=0.866501 at t=9.33333. Previous value was 0.853645.
# <Alter 253>: set PQ.PQ_2.Ppf.v=0.881373 at t=9.36667. Previous value was 0.866501.
# <Alter 254>: set PQ.PQ_2.Ppf.v=0.897985 at t=9.4. Previous value was 0.881373.
# <Alter 255>: set PQ.PQ_2.Ppf.v=0.916016 at t=9.43333. Previous value was 0.897985.
# <Alter 256>: set PQ.PQ_2.Ppf.v=0.935105 at t=9.46667. Previous value was 0.916016.
# <Alter 257>: set PQ.PQ_2.Ppf.v=0.954858 at t=9.5. Previous value was 0.935105.
# <Alter 258>: set PQ.PQ_2.Ppf.v=0.974858 at t=9.53333. Previous value was 0.954858.
# <Alter 259>: set PQ.PQ_2.Ppf.v=0.994665 at t=9.56667. Previous value was 0.974858.
# <Alter 260>: set PQ.PQ_2.Ppf.v=1.01384 at t=9.6. Previous value was 0.994665.
# <Alter 261>: set PQ.PQ_2.Ppf.v=1.03193 at t=9.63333. Previous value was 1.01384.
# <Alter 262>: set PQ.PQ_2.Ppf.v=1.04851 at t=9.66667. Previous value was 1.03193.
# <Alter 263>: set PQ.PQ_2.Ppf.v=1.06317 at t=9.7. Previous value was 1.04851.
# <Alter 264>: set PQ.PQ_2.Ppf.v=1.07555 at t=9.73333. Previous value was 1.06317.
# <Alter 265>: set PQ.PQ_2.Ppf.v=1.08532 at t=9.76667. Previous value was 1.07555.
# <Alter 266>: set PQ.PQ_2.Ppf.v=1.09221 at t=9.8. Previous value was 1.08532.
# <Alter 267>: set PQ.PQ_2.Ppf.v=1.09603 at t=9.83333. Previous value was 1.09221.
# <Alter 268>: set PQ.PQ_2.Ppf.v=1.09664 at t=9.86667. Previous value was 1.09603.
# <Alter 269>: set PQ.PQ_2.Ppf.v=1.09401 at t=9.9. Previous value was 1.09664.
# <Alter 270>: set PQ.PQ_2.Ppf.v=1.08818 at t=9.93333. Previous value was 1.09401.
# <Alter 271>: set PQ.PQ_2.Ppf.v=1.07927 at t=9.96667. Previous value was 1.08818.
# <Alter 272>: set PQ.PQ_2.Ppf.v=1.06752 at t=10. Previous value was 1.07927.
# <Alter 273>: set PQ.PQ_2.Ppf.v=1.05322 at t=10.0333. Previous value was 1.06752.
# <Alter 274>: set PQ.PQ_2.Ppf.v=1.03676 at t=10.0667. Previous value was 1.05322.
# <Alter 275>: set PQ.PQ_2.Ppf.v=1.01861 at t=10.1. Previous value was 1.03676.
# <Alter 276>: set PQ.PQ_2.Ppf.v=0.999291 at t=10.1333. Previous value was 1.01861.
# <Alter 277>: set PQ.PQ_2.Ppf.v=0.979368 at t=10.1667. Previous value was 0.999291.
# <Alter 278>: set PQ.PQ_2.Ppf.v=0.959445 at t=10.2. Previous value was 0.979368.
# <Alter 279>: set PQ.PQ_2.Ppf.v=0.940141 at t=10.2333. Previous value was 0.959445.
# <Alter 280>: set PQ.PQ_2.Ppf.v=0.922068 at t=10.2667. Previous value was 0.940141.
# <Alter 281>: set PQ.PQ_2.Ppf.v=0.905814 at t=10.3. Previous value was 0.922068.
# <Alter 282>: set PQ.PQ_2.Ppf.v=0.891921 at t=10.3333. Previous value was 0.905814.
# <Alter 283>: set PQ.PQ_2.Ppf.v=0.880865 at t=10.3667. Previous value was 0.891921.
# <Alter 284>: set PQ.PQ_2.Ppf.v=0.873037 at t=10.4. Previous value was 0.880865.
# <Alter 285>: set PQ.PQ_2.Ppf.v=0.868729 at t=10.4333. Previous value was 0.873037.
# <Alter 286>: set PQ.PQ_2.Ppf.v=0.868115 at t=10.4667. Previous value was 0.868729.
# <Alter 287>: set PQ.PQ_2.Ppf.v=0.871244 at t=10.5. Previous value was 0.868115.
# <Alter 288>: set PQ.PQ_2.Ppf.v=0.878031 at t=10.5333. Previous value was 0.871244.
# <Alter 289>: set PQ.PQ_2.Ppf.v=0.88826 at t=10.5667. Previous value was 0.878031.
# <Alter 290>: set PQ.PQ_2.Ppf.v=0.901581 at t=10.6. Previous value was 0.88826.
# <Alter 291>: set PQ.PQ_2.Ppf.v=0.91752 at t=10.6333. Previous value was 0.901581.
# <Alter 292>: set PQ.PQ_2.Ppf.v=0.935495 at t=10.6667. Previous value was 0.91752.
# <Alter 293>: set PQ.PQ_2.Ppf.v=0.954835 at t=10.7. Previous value was 0.935495.
# <Alter 294>: set PQ.PQ_2.Ppf.v=0.974799 at t=10.7333. Previous value was 0.954835.
# <Alter 295>: set PQ.PQ_2.Ppf.v=0.994607 at t=10.7667. Previous value was 0.974799.
# <Alter 296>: set PQ.PQ_2.Ppf.v=1.01347 at t=10.8. Previous value was 0.994607.
# <Alter 297>: set PQ.PQ_2.Ppf.v=1.03061 at t=10.8333. Previous value was 1.01347.
# <Alter 298>: set PQ.PQ_2.Ppf.v=1.04532 at t=10.8667. Previous value was 1.03061.
# <Alter 299>: set PQ.PQ_2.Ppf.v=1.05698 at t=10.9. Previous value was 1.04532.
# <Alter 300>: set PQ.PQ_2.Ppf.v=1.06506 at t=10.9333. Previous value was 1.05698.
# <Alter 301>: set PQ.PQ_2.Ppf.v=1.0692 at t=10.9667. Previous value was 1.06506.
# <Alter 302>: set PQ.PQ_2.Ppf.v=1.0692 at t=11. Previous value was 1.0692.
# <Alter 303>: set PQ.PQ_10.Ppf.v=0.135 at t=12. Previous value was 0.135.
# <Alter 304>: set PQ.PQ_10.Ppf.v=0.135014 at t=12.0333. Previous value was 0.135.
# <Alter 305>: set PQ.PQ_10.Ppf.v=0.13507 at t=12.0667. Previous value was 0.135014.
# <Alter 306>: set PQ.PQ_10.Ppf.v=0.135195 at t=12.1. Previous value was 0.13507.
# <Alter 307>: set PQ.PQ_10.Ppf.v=0.135419 at t=12.1333. Previous value was 0.135195.
# <Alter 308>: set PQ.PQ_10.Ppf.v=0.135768 at t=12.1667. Previous value was 0.135419.
# <Alter 309>: set PQ.PQ_10.Ppf.v=0.136271 at t=12.2. Previous value was 0.135768.
# <Alter 310>: set PQ.PQ_10.Ppf.v=0.136955 at t=12.2333. Previous value was 0.136271.
# <Alter 311>: set PQ.PQ_10.Ppf.v=0.137848 at t=12.2667. Previous value was 0.136955.
# <Alter 312>: set PQ.PQ_10.Ppf.v=0.138978 at t=12.3. Previous value was 0.137848.
# <Alter 313>: set PQ.PQ_10.Ppf.v=0.140373 at t=12.3333. Previous value was 0.138978.
# <Alter 314>: set PQ.PQ_10.Ppf.v=0.142061 at t=12.3667. Previous value was 0.140373.
# <Alter 315>: set PQ.PQ_10.Ppf.v=0.144068 at t=12.4. Previous value was 0.142061.
# <Alter 316>: set PQ.PQ_10.Ppf.v=0.146422 at t=12.4333. Previous value was 0.144068.
# <Alter 317>: set PQ.PQ_10.Ppf.v=0.14915 at t=12.4667. Previous value was 0.146422.
# <Alter 318>: set PQ.PQ_10.Ppf.v=0.152279 at t=12.5. Previous value was 0.14915.
# <Alter 319>: set PQ.PQ_10.Ppf.v=0.155835 at t=12.5333. Previous value was 0.152279.
# <Alter 320>: set PQ.PQ_10.Ppf.v=0.159842 at t=12.5667. Previous value was 0.155835.
# <Alter 321>: set PQ.PQ_10.Ppf.v=0.164328 at t=12.6. Previous value was 0.159842.
# <Alter 322>: set PQ.PQ_10.Ppf.v=0.169315 at t=12.6333. Previous value was 0.164328.
# <Alter 323>: set PQ.PQ_10.Ppf.v=0.174828 at t=12.6667. Previous value was 0.169315.
# <Alter 324>: set PQ.PQ_10.Ppf.v=0.180889 at t=12.7. Previous value was 0.174828.
# <Alter 325>: set PQ.PQ_10.Ppf.v=0.187519 at t=12.7333. Previous value was 0.180889.
# <Alter 326>: set PQ.PQ_10.Ppf.v=0.194738 at t=12.7667. Previous value was 0.187519.
# <Alter 327>: set PQ.PQ_10.Ppf.v=0.202566 at t=12.8. Previous value was 0.194738.
# <Alter 328>: set PQ.PQ_10.Ppf.v=0.211018 at t=12.8333. Previous value was 0.202566.
# <Alter 329>: set PQ.PQ_10.Ppf.v=0.22011 at t=12.8667. Previous value was 0.211018.
# <Alter 330>: set PQ.PQ_10.Ppf.v=0.229855 at t=12.9. Previous value was 0.22011.
# <Alter 331>: set PQ.PQ_10.Ppf.v=0.240264 at t=12.9333. Previous value was 0.229855.
# <Alter 332>: set PQ.PQ_10.Ppf.v=0.251343 at t=12.9667. Previous value was 0.240264.
# <Alter 333>: set PQ.PQ_10.Ppf.v=0.263099 at t=13. Previous value was 0.251343.
# <Alter 334>: set PQ.PQ_10.Ppf.v=0.275533 at t=13.0333. Previous value was 0.263099.
# <Alter 335>: set PQ.PQ_10.Ppf.v=0.288643 at t=13.0667. Previous value was 0.275533.
# <Alter 336>: set PQ.PQ_10.Ppf.v=0.302425 at t=13.1. Previous value was 0.288643.
# <Alter 337>: set PQ.PQ_10.Ppf.v=0.31687 at t=13.1333. Previous value was 0.302425.
# <Alter 338>: set PQ.PQ_10.Ppf.v=0.331965 at t=13.1667. Previous value was 0.31687.
# <Alter 339>: set PQ.PQ_10.Ppf.v=0.34769 at t=13.2. Previous value was 0.331965.
# <Alter 340>: set PQ.PQ_10.Ppf.v=0.364025 at t=13.2333. Previous value was 0.34769.
# <Alter 341>: set PQ.PQ_10.Ppf.v=0.380942 at t=13.2667. Previous value was 0.364025.
# <Alter 342>: set PQ.PQ_10.Ppf.v=0.398407 at t=13.3. Previous value was 0.380942.
# <Alter 343>: set PQ.PQ_10.Ppf.v=0.416383 at t=13.3333. Previous value was 0.398407.
# <Alter 344>: set PQ.PQ_10.Ppf.v=0.434825 at t=13.3667. Previous value was 0.416383.
# <Alter 345>: set PQ.PQ_10.Ppf.v=0.453685 at t=13.4. Previous value was 0.434825.
# <Alter 346>: set PQ.PQ_10.Ppf.v=0.472907 at t=13.4333. Previous value was 0.453685.
# <Alter 347>: set PQ.PQ_10.Ppf.v=0.492428 at t=13.4667. Previous value was 0.472907.
# <Alter 348>: set PQ.PQ_10.Ppf.v=0.512182 at t=13.5. Previous value was 0.492428.
# <Alter 349>: set PQ.PQ_10.Ppf.v=0.532094 at t=13.5333. Previous value was 0.512182.
# <Alter 350>: set PQ.PQ_10.Ppf.v=0.552086 at t=13.5667. Previous value was 0.532094.
# <Alter 351>: set PQ.PQ_10.Ppf.v=0.572072 at t=13.6. Previous value was 0.552086.
# <Alter 352>: set PQ.PQ_10.Ppf.v=0.591961 at t=13.6333. Previous value was 0.572072.
# <Alter 353>: set PQ.PQ_10.Ppf.v=0.611657 at t=13.6667. Previous value was 0.591961.
# <Alter 354>: set PQ.PQ_10.Ppf.v=0.63106 at t=13.7. Previous value was 0.611657.
# <Alter 355>: set PQ.PQ_10.Ppf.v=0.650063 at t=13.7333. Previous value was 0.63106.
# <Alter 356>: set PQ.PQ_10.Ppf.v=0.66856 at t=13.7667. Previous value was 0.650063.
# <Alter 357>: set PQ.PQ_10.Ppf.v=0.686436 at t=13.8. Previous value was 0.66856.
# <Alter 358>: set PQ.PQ_10.Ppf.v=0.70358 at t=13.8333. Previous value was 0.686436.
# <Alter 359>: set PQ.PQ_10.Ppf.v=0.719874 at t=13.8667. Previous value was 0.70358.
# <Alter 360>: set PQ.PQ_10.Ppf.v=0.735204 at t=13.9. Previous value was 0.719874.
# <Alter 361>: set PQ.PQ_10.Ppf.v=0.749454 at t=13.9333. Previous value was 0.735204.
# <Alter 362>: set PQ.PQ_10.Ppf.v=0.762512 at t=13.9667. Previous value was 0.749454.
# <Alter 363>: set PQ.PQ_10.Ppf.v=0.774268 at t=14. Previous value was 0.762512.
# <Alter 364>: set PQ.PQ_10.Ppf.v=0.784617 at t=14.0333. Previous value was 0.774268.
# <Alter 365>: set PQ.PQ_10.Ppf.v=0.793459 at t=14.0667. Previous value was 0.784617.
# <Alter 366>: set PQ.PQ_10.Ppf.v=0.800705 at t=14.1. Previous value was 0.793459.
# <Alter 367>: set PQ.PQ_10.Ppf.v=0.806271 at t=14.1333. Previous value was 0.800705.
# <Alter 368>: set PQ.PQ_10.Ppf.v=0.810087 at t=14.1667. Previous value was 0.806271.
# <Alter 369>: set PQ.PQ_10.Ppf.v=0.812094 at t=14.2. Previous value was 0.810087.
# <Alter 370>: set PQ.PQ_10.Ppf.v=0.812248 at t=14.2333. Previous value was 0.812094.
# <Alter 371>: set PQ.PQ_10.Ppf.v=0.810519 at t=14.2667. Previous value was 0.812248.
# <Alter 372>: set PQ.PQ_10.Ppf.v=0.806895 at t=14.3. Previous value was 0.810519.
# <Alter 373>: set PQ.PQ_10.Ppf.v=0.801382 at t=14.3333. Previous value was 0.806895.
# <Alter 374>: set PQ.PQ_10.Ppf.v=0.794007 at t=14.3667. Previous value was 0.801382.
# <Alter 375>: set PQ.PQ_10.Ppf.v=0.784815 at t=14.4. Previous value was 0.794007.
# <Alter 376>: set PQ.PQ_10.Ppf.v=0.773875 at t=14.4333. Previous value was 0.784815.
# <Alter 377>: set PQ.PQ_10.Ppf.v=0.761278 at t=14.4667. Previous value was 0.773875.
# <Alter 378>: set PQ.PQ_10.Ppf.v=0.747136 at t=14.5. Previous value was 0.761278.
# <Alter 379>: set PQ.PQ_10.Ppf.v=0.731584 at t=14.5333. Previous value was 0.747136.
# <Alter 380>: set PQ.PQ_10.Ppf.v=0.714781 at t=14.5667. Previous value was 0.731584.
# <Alter 381>: set PQ.PQ_10.Ppf.v=0.696904 at t=14.6. Previous value was 0.714781.
# <Alter 382>: set PQ.PQ_10.Ppf.v=0.678153 at t=14.6333. Previous value was 0.696904.
# <Alter 383>: set PQ.PQ_10.Ppf.v=0.658747 at t=14.6667. Previous value was 0.678153.
# <Alter 384>: set PQ.PQ_10.Ppf.v=0.638921 at t=14.7. Previous value was 0.658747.
# <Alter 385>: set PQ.PQ_10.Ppf.v=0.618924 at t=14.7333. Previous value was 0.638921.
# <Alter 386>: set PQ.PQ_10.Ppf.v=0.599018 at t=14.7667. Previous value was 0.618924.
# <Alter 387>: set PQ.PQ_10.Ppf.v=0.579473 at t=14.8. Previous value was 0.599018.
# <Alter 388>: set PQ.PQ_10.Ppf.v=0.560563 at t=14.8333. Previous value was 0.579473.
# <Alter 389>: set PQ.PQ_10.Ppf.v=0.542562 at t=14.8667. Previous value was 0.560563.
# <Alter 390>: set PQ.PQ_10.Ppf.v=0.525744 at t=14.9. Previous value was 0.542562.
# <Alter 391>: set PQ.PQ_10.Ppf.v=0.510369 at t=14.9333. Previous value was 0.525744.
# <Alter 392>: set PQ.PQ_10.Ppf.v=0.496688 at t=14.9667. Previous value was 0.510369.
# <Alter 393>: set PQ.PQ_10.Ppf.v=0.484933 at t=15. Previous value was 0.496688.
# <Alter 394>: set PQ.PQ_10.Ppf.v=0.47531 at t=15.0333. Previous value was 0.484933.
# <Alter 395>: set PQ.PQ_10.Ppf.v=0.467999 at t=15.0667. Previous value was 0.47531.
# <Alter 396>: set PQ.PQ_10.Ppf.v=0.463147 at t=15.1. Previous value was 0.467999.
# <Alter 397>: set PQ.PQ_10.Ppf.v=0.460862 at t=15.1333. Previous value was 0.463147.
# <Alter 398>: set PQ.PQ_10.Ppf.v=0.461211 at t=15.1667. Previous value was 0.460862.
# <Alter 399>: set PQ.PQ_10.Ppf.v=0.464216 at t=15.2. Previous value was 0.461211.
# <Alter 400>: set PQ.PQ_10.Ppf.v=0.469849 at t=15.2333. Previous value was 0.464216.
# <Alter 401>: set PQ.PQ_10.Ppf.v=0.478035 at t=15.2667. Previous value was 0.469849.
# <Alter 402>: set PQ.PQ_10.Ppf.v=0.488645 at t=15.3. Previous value was 0.478035.
# <Alter 403>: set PQ.PQ_10.Ppf.v=0.501501 at t=15.3333. Previous value was 0.488645.
# <Alter 404>: set PQ.PQ_10.Ppf.v=0.516373 at t=15.3667. Previous value was 0.501501.
# <Alter 405>: set PQ.PQ_10.Ppf.v=0.532985 at t=15.4. Previous value was 0.516373.
# <Alter 406>: set PQ.PQ_10.Ppf.v=0.551016 at t=15.4333. Previous value was 0.532985.
# <Alter 407>: set PQ.PQ_10.Ppf.v=0.570105 at t=15.4667. Previous value was 0.551016.
# <Alter 408>: set PQ.PQ_10.Ppf.v=0.589858 at t=15.5. Previous value was 0.570105.
# <Alter 409>: set PQ.PQ_10.Ppf.v=0.609858 at t=15.5333. Previous value was 0.589858.
# <Alter 410>: set PQ.PQ_10.Ppf.v=0.629665 at t=15.5667. Previous value was 0.609858.
# <Alter 411>: set PQ.PQ_10.Ppf.v=0.648835 at t=15.6. Previous value was 0.629665.
# <Alter 412>: set PQ.PQ_10.Ppf.v=0.666926 at t=15.6333. Previous value was 0.648835.
# <Alter 413>: set PQ.PQ_10.Ppf.v=0.683507 at t=15.6667. Previous value was 0.666926.
# <Alter 414>: set PQ.PQ_10.Ppf.v=0.698172 at t=15.7. Previous value was 0.683507.
# <Alter 415>: set PQ.PQ_10.Ppf.v=0.710551 at t=15.7333. Previous value was 0.698172.
# <Alter 416>: set PQ.PQ_10.Ppf.v=0.72032 at t=15.7667. Previous value was 0.710551.
# <Alter 417>: set PQ.PQ_10.Ppf.v=0.727213 at t=15.8. Previous value was 0.72032.
# <Alter 418>: set PQ.PQ_10.Ppf.v=0.731029 at t=15.8333. Previous value was 0.727213.
# <Alter 419>: set PQ.PQ_10.Ppf.v=0.731644 at t=15.8667. Previous value was 0.731029.
# <Alter 420>: set PQ.PQ_10.Ppf.v=0.729012 at t=15.9. Previous value was 0.731644.
# <Alter 421>: set PQ.PQ_10.Ppf.v=0.723178 at t=15.9333. Previous value was 0.729012.
# <Alter 422>: set PQ.PQ_10.Ppf.v=0.714273 at t=15.9667. Previous value was 0.723178.
# <Alter 423>: set PQ.PQ_10.Ppf.v=0.702517 at t=16. Previous value was 0.714273.
# <Alter 424>: set PQ.PQ_10.Ppf.v=0.688218 at t=16.0333. Previous value was 0.702517.
# <Alter 425>: set PQ.PQ_10.Ppf.v=0.671763 at t=16.0667. Previous value was 0.688218.
# <Alter 426>: set PQ.PQ_10.Ppf.v=0.653614 at t=16.1. Previous value was 0.671763.
# <Alter 427>: set PQ.PQ_10.Ppf.v=0.634291 at t=16.1333. Previous value was 0.653614.
# <Alter 428>: set PQ.PQ_10.Ppf.v=0.614368 at t=16.1667. Previous value was 0.634291.
# <Alter 429>: set PQ.PQ_10.Ppf.v=0.594445 at t=16.2. Previous value was 0.614368.
# <Alter 430>: set PQ.PQ_10.Ppf.v=0.575141 at t=16.2333. Previous value was 0.594445.
# <Alter 431>: set PQ.PQ_10.Ppf.v=0.557068 at t=16.2667. Previous value was 0.575141.
# <Alter 432>: set PQ.PQ_10.Ppf.v=0.540814 at t=16.3. Previous value was 0.557068.
# <Alter 433>: set PQ.PQ_10.Ppf.v=0.526921 at t=16.3333. Previous value was 0.540814.
# <Alter 434>: set PQ.PQ_10.Ppf.v=0.515865 at t=16.3667. Previous value was 0.526921.
# <Alter 435>: set PQ.PQ_10.Ppf.v=0.508037 at t=16.4. Previous value was 0.515865.
# <Alter 436>: set PQ.PQ_10.Ppf.v=0.503729 at t=16.4333. Previous value was 0.508037.
# <Alter 437>: set PQ.PQ_10.Ppf.v=0.503115 at t=16.4667. Previous value was 0.503729.
# <Alter 438>: set PQ.PQ_10.Ppf.v=0.506244 at t=16.5. Previous value was 0.503115.
# <Alter 439>: set PQ.PQ_10.Ppf.v=0.513031 at t=16.5333. Previous value was 0.506244.
# <Alter 440>: set PQ.PQ_10.Ppf.v=0.52326 at t=16.5667. Previous value was 0.513031.
# <Alter 441>: set PQ.PQ_10.Ppf.v=0.536581 at t=16.6. Previous value was 0.52326.
# <Alter 442>: set PQ.PQ_10.Ppf.v=0.55252 at t=16.6333. Previous value was 0.536581.
# <Alter 443>: set PQ.PQ_10.Ppf.v=0.570495 at t=16.6667. Previous value was 0.55252.
# <Alter 444>: set PQ.PQ_10.Ppf.v=0.589835 at t=16.7. Previous value was 0.570495.
# <Alter 445>: set PQ.PQ_10.Ppf.v=0.609799 at t=16.7333. Previous value was 0.589835.
# <Alter 446>: set PQ.PQ_10.Ppf.v=0.629607 at t=16.7667. Previous value was 0.609799.
# <Alter 447>: set PQ.PQ_10.Ppf.v=0.648467 at t=16.8. Previous value was 0.629607.
# <Alter 448>: set PQ.PQ_10.Ppf.v=0.66561 at t=16.8333. Previous value was 0.648467.
# <Alter 449>: set PQ.PQ_10.Ppf.v=0.680322 at t=16.8667. Previous value was 0.66561.
# <Alter 450>: set PQ.PQ_10.Ppf.v=0.691976 at t=16.9. Previous value was 0.680322.
# <Alter 451>: set PQ.PQ_10.Ppf.v=0.70006 at t=16.9333. Previous value was 0.691976.
# <Alter 452>: set PQ.PQ_10.Ppf.v=0.704204 at t=16.9667. Previous value was 0.70006.
# <Alter 453>: set PQ.PQ_10.Ppf.v=0.704204 at t=17. Previous value was 0.704204.
# Simulation finished
# /opt/anaconda3/envs/controls/lib/python3.13/site-packages/andes/plot.py:822: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/ft/6qjq8bkn2j1300glgtw50r8r0000gn/T/ipykernel_74752/1911045503.py:30: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /opt/anaconda3/envs/controls/lib/python3.13/site-packages/andes/plot.py:822: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# Extract simulation (time-series) data 
data = ssys.dae.ts

# Extract variables of interest (time, frequency, voltages)
time = data.time
omega = data.x[:, ssys.GENROU.omega.a]
Vbus = data.y[:, ssys.Bus.v.a]
# Out:
# Time steps:  [0.00000e+00 1.00000e-04 2.01000e-02 ... 1.99601e+01 1.99801e+01
#  2.00000e+01]

# %% [markdown]
# # System Identification
# Model predictive control requires a state-space model.
# Consider the discrete-time linear time-invariant (LTI) system
#
# $$
# x_{k+1} = A\,x_k + B\,u_k,
# $$
# $$
# y_k = C\, x_k + B\,u_k
# $$
#
# System identification is use to estimate the matrices $A, B, C$, and $D$. SIPPY, an open-source system identification package, is used to estimate matrices A, B, C, and D.The dynamic ANDES simulation data is used for system identification. We used N4SID as the method for system identification {cite}.
#
#
#
# Note on model order:

# %%
# 4) Subspace identification (N4SID) to obtain a reduced-order discrete-time model
# We'll identify a single MIMO model with inputs u (3) and outputs y (freq + voltages)

Y = df[['freq_dev'] + [f'V_b{b}' for b in buses_of_interest]].values
print('Output Y shape:', Y.shape)
U = df[[f'u{j+1}' for j in range(u.shape[1])]].values
print('Input U shape:', U.shape)
# Downsample data to reduce computation for identification (optional)


# Choose model order (experiment with this)
model_order = 17
print('Running N4SID (this may take a few seconds)...')
model = sysid(Y, U, 'N4SID', SS_fixed_order=model_order)

A_id = np.array(model.A)
B_id = np.array(model.B)
C_id = np.array(model.C)
D_id = np.array(model.D)
print('Identified model shapes: A', A_id.shape, 'B', B_id.shape, 'C', C_id.shape, 'D', D_id.shape)


# Convert identified model to discrete-time state-space in control package
sys_id = ss(A_id, B_id, C_id, D_id)
print('Identified discrete-time state-space model: \n', sys_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # 4) Subspace identification (N4SID) to obtain a reduced-order discrete-time model
#       2 # We'll identify a single MIMO model with inputs u (3) and outputs y (freq + voltages)
# ----> 4 Y = df[['freq_dev'] + [f'V_b{b}' for b in buses_of_interest]].values
#       5 print('Output Y shape:', Y.shape)
#       6 U = df[[f'u{j+1}' for j in range(u.shape[1])]].values
#
# NameError: name 'df' is not defined
